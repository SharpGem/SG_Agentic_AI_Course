# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key not set (and this is optional)
# Google API Key not set (and this is optional)
# DeepSeek API Key not set (and this is optional)
# Groq API Key not set (and this is optional)

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'}]

# %%
openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=messages,
)
question = response.choices[0].message.content
print(question)
# Out:
# Imagine you are advising the government of a small island nation with 500,000 people that is facing three simultaneous crises: a novel respiratory virus of unknown transmissibility and severity, a category-4 storm that has damaged power, water, and two of the three hospitals, and an imminent national election in six weeks likely to change the leadership; you have 48 hours, an operational budget of $5M, access to sparse hospital reports (aggregate admissions and deaths with inconsistent timestamps), demographic census data, satellite imagery, and a diagnostic capacity of 1,000 tests/day with 48-hour turnaround—given these constraints, (a) provide a prioritized 7-step operational and policy plan for the next 30 days, (b) list and quantify the key assumptions you are making (with plausible ranges and confidence levels), (c) produce best/median/worst-case numeric projections of infections, hospitalizations, deaths, and direct economic loss over 6 months under your plan, (d) describe three highest-value data-collection/experiments you would run in the next 7 days to reduce uncertainty and exactly how you would implement them with the available resources, (e) identify at least five distinct failure modes for your plan with concrete mitigations and early-warning indicators, and (f) say which three pieces of additional information (if obtained immediately) would most change your recommended course of action and why?

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %% [markdown]
# ## Note - update since the videos
#
# I've updated the model names to use the latest models below, like GPT 5 and Claude Sonnet 4.5. It's worth noting that these models can be quite slow - like 1-2 minutes - but they do a great job! Feel free to switch them for faster models if you'd prefer, like the ones I use in the video.

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Imagine you are advising the government of a small island nation with 500,000 people that is facing three simultaneous crises: a novel respiratory virus of unknown transmissibility and severity, a category-4 storm that has damaged power, water, and two of the three hospitals, and an imminent national election in six weeks likely to change the leadership; you have 48 hours, an operational budget of $5M, access to sparse hospital reports (aggregate admissions and deaths with inconsistent timestamps), demographic census data, satellite imagery, and a diagnostic capacity of 1,000 tests/day with 48-hour turnaround—given these constraints, (a) provide a prioritized 7-step operational and policy plan for the next 30 days, (b) list and quantify the key assumptions you are making (with plausible ranges and confidence levels), (c) produce best/median/worst-case numeric projections of infections, hospitalizations, deaths, and direct economic loss over 6 months under your plan, (d) describe three highest-value data-collection/experiments you would run in the next 7 days to reduce uncertainty and exactly how you would implement them with the available resources, (e) identify at least five distinct failure modes for your plan with concrete mitigations and early-warning indicators, and (f) say which three pieces of additional information (if obtained immediately) would most change your recommended course of action and why?'}]

# %%
# The API we know well
# I've updated this with the latest model, but it can take some time because it likes to think!
# Replace the model with gpt-4.1-mini if you'd prefer not to wait 1-2 mins

model_name = "gpt-5-nano"

response = openai.chat.completions.create(
    model=model_name, 
    messages=messages
)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Below is a compact, actionable plan tailored to the constraints you described. It is organized to (a) deliver a 7-step plan for the next 30 days, (b) spell out key assumptions with ranges and confidence, (c) provide best/median/worst-case projections for 6 months, (d) describe three high-value data experiments with implementation details, (e) identify major failure modes with mitigations and early-warning indicators, and (f) name the three most impactful additional data pieces that would most change the plan if obtained immediately. All figures are illustrative and explicitly caveated for uncertainty.
#
# Important note
# - This is a hypothetical, crisis-management scenario. All numbers are estimates given the constraints (500,000 people, 48-hour test results, 1,000 tests/day, 48-hour turnaround, 2 hospitals damaged, 1 hospital functioning, impending election in 6 weeks, budget cap of $5M). Real-world decisions should be guided by locally vetted epidemiologists, engineers, and logistics experts.
#
# (a) Prioritized 7-step operational and policy plan for the next 30 days
#
# 1) Establish unified crisis governance and rapid decision cadence
# - Create an Incident Command System with a small core (prime minister/health lead, Emergency Operations Center director, hospital leadership, logistics and communications heads).
# - Clear decision rights, daily 60-minute situational briefing, and a single public dashboard to avoid mixed messaging.
# - Budget focus: fund the core team and communications (roughly $0.3–0.5M out of $5M).
# - Key outputs this step delivers: a single source of truth, explicit authority for rapid procurement and deviations from normal policy.
#
# 2) Stabilize critical infrastructure and surge health capacity
# - Rapidly assess and restore or substitute power and water in critical facilities; authorize mobile/helicopter-delivery of essential supplies if needed.
# - Activate temporary/field hospital capacity and expand outpatient/triage clinics; re-purpose clinics as isolation spaces; triage to keep the functioning hospital from being overwhelmed.
# - Short-term staffing plan: deploy retired/retired-on-call clinicians, local volunteers, and cross-train existing staff; implement rigorous infection control and shift rotations.
# - Budget focus: approximately $2.0–$2.5M for site repairs, temporary facilities, fuel, generators, oxygen systems, and staffing bonuses.
#
# 3) Targeted testing, surveillance, and prioritization strategy
# - With 1,000 tests/day and 48-hour turnaround, implement a tiered testing approach:
#   - Symptomatic/high-risk frontline workers and hospitalized patients prioritized for immediate testing.
#   - Sentinel testing in 6–12 communities or clinics to estimate spread; leverage existing aggregate admissions data to interpret trends.
#   - Use RT-PCR as the primary test; reserve rapid antigen tests to reduce turnaround for triage when feasible (if available).
# - Build a daily data view combining admissions/deaths (even if timestamps are inconsistent) with sentinel results to estimate Rt and trajectory.
# - Budget focus: ~$0.8–$1.0M for test kits, swabs, consumables, lab logistics, temporary lab capacity, and hazard pay for testing staff.
#
# 4) Nonpharmaceutical interventions and risk-based containment
# - Implement risk-based NPIs rather than broad nationwide restrictions to preserve governance and economy:
#   - Indoor masking in high-risk settings (healthcare, public transport, markets) for 4–6 weeks, escalating or relaxing based on Rt.
#   - Targeted closures or restrictions in high-transmission clusters (schools or events) rather than blanket policies.
#   - Entry screening and traveler advisories if importation risk is non-negligible.
# - Keep schools and essential services operating with safety protocols; maintain election logistics with health safeguards.
# - Budget focus: ~$0.3–0.5M for enforcement, PPE, public communications, and compliance monitoring.
#
# 5) Patient care optimization and community-based care
# - Accelerate discharge planning from hospitals; develop home- or community-based care with mobile teams (oxygen/antibody/antiviral logistics if available), and set up temporary oxygen therapy through mobile units where oxygen supply is constrained.
# - Create a centralized supply chain and distribution hub for PPE, oxygen, essential medicines (if any), and fuel.
# - Budget focus: ~$0.4–0.6M for protective equipment, oxygen concentrators, home-care kits, and logistics.
#
# 6) Real-time data, modeling, and adaptive decision framework
# - Build a simple, transparent dashboard combining:
#   - Aggregate admissions and deaths (correcting for missing timestamps where possible).
#   - Sentinel test results, positivity rate, and estimated Rt.
#   - Hospital bed occupancy, ICU, oxygen supply, staff counts, and field-hospital capacity.
# - Use this to inform threshold-based actions (when to tighten/loosen NPIs, when to scale field capacity).
# - Budget focus: ~$0.2–0.4M for data systems and analytics support.
#
# 7) Election continuity and risk communications, governance safeguards
# - Protect essential health services during the election period; ensure nonpartisan, evidence-based public messaging.
# - Pre-commit to a transparent post-election plan for health governance, to reduce risk of political missteps during the crisis.
# - Budget focus: ~$0.15–0.25M for communications and public information campaigns.
#
# Total budget guidance (rough, within a $5M cap)
# - Step 1: ~0.3–0.5M
# - Step 2: ~2.0–2.5M
# - Step 3: ~0.8–1.0M
# - Step 4: ~0.3–0.5M
# - Step 5: ~0.4–0.6M
# - Step 6: ~0.2–0.4M
# - Step 7: ~0.15–0.25M
# - Contingency and cross-cutting needs: remainder to cover unexpected spikes or storm-related costs.
#
# (b) Key assumptions (with plausible ranges and confidence)
#
# Epidemiology and virus characteristics (uncertain; use ranges)
# - Basic reproduction number (R0) for initial phase: 1.5–3.5
#   - Confidence: Low–Medium (depends on unknown virus and social behavior)
# - Effective reproduction number (Rt) under plan in the next 30 days with NPIs: 0.9–1.6 in best/median/worst arms
#   - Confidence: Medium
# - Incubation period: 2–7 days (mean ~5 days)
#   - Confidence: High
# - Time from symptom onset to hospital admission (average): 3–7 days
#   - Confidence: Medium
# - Proportion exposed who become symptomatic: 50–90%
#   - Confidence: Low–Medium (depends on virus)
# - Case hospitalization rate (CHR) among symptomatic: 2–8%
#   - Confidence: Medium
# - Case fatality rate (CFR) among confirmed cases: 0.2–2% (depending on access to care)
#   - Confidence: Medium–Low (data-poor; high uncertainty)
# - Asymptomatic proportion: 20–60%
#   - Confidence: Low–Medium
#
# Testing and data quality
# - Test sensitivity (PCR): 85–98% (dependent on sample quality and timing)
#   - Confidence: Medium
# - Test specificity: ~99%
#   - Confidence: High
# - Turnaround time (given): 48 hours
#   - Confidence: High
# - Daily testing capacity: 1,000 tests/day
#   - Confidence: High
# - Data quality of hospital reports (aggregate, with inconsistent timestamps): low-to-moderate initially; improvement over 2–3 weeks
#   - Confidence: Medium
#
# Health system capacity and storm impact
# - Functioning hospital capacity: 1 functioning hospital; 2 damaged (degraded capacity)
#   - Confidence: High (scenario given)
# - Temporary/field hospital capacity achievable within 2–3 weeks: 150–300 beds
#   - Confidence: Medium
# - Oxygen supply and critical equipment post-storm: precarious but improvable with imports and mobile units
#   - Confidence: Medium
# - Health workforce availability after surge: 20–40% of baseline shortfall initially, improving with shifts
#   - Confidence: Medium
#
# Economic and social
# - Baseline annual GDP per capita and island GDP scale (for indirect losses): order of magnitude plausible for a small island nation; use local estimates
#   - Confidence: Low–Medium (depends on country)
# - Direct economic losses due to outbreak and storm disruption over 6 months: 0.5–2.0x 6-month GDP in worst case
#   - Confidence: Medium
#
# Policy and compliance
# - Public compliance with NPIs: 40–80% depending on trust and communication
#   - Confidence: Medium
# - Election-related risk and turnout impact: moderate; risk managed with nonpartisan communications
#   - Confidence: Medium
#
# (c) Best/median/worst-case projections for infections, hospitalizations, deaths, and direct economic loss over 6 months under the plan
#
# Assumptions used for projections
# - 500,000 population
# - 6-month horizon
# - Rt estimates reflect the combination of NPIs, testing, healthcare capacity, and behavior described in the plan
# - Hospitalization rate (CHR) ~ 3–7% of symptomatic infections (baseline assumption)
# - CFR in line with CHR and health system capacity, with 0.2–2% CFR range
#
# Best-case scenario (strong suppression, effective surge capacity, high compliance)
# - Cumulative infections: 50,000–75,000 (10–15% of population)
# - Hospitalizations: 500–1,500
# - Deaths: 50–250
# - Direct economic loss (net, six months): $200–300 million (approx. 10–15% of 6-month GDP, depending on baseline GDP)
# - Key drivers: Rt ~ 0.9–1.0 for most of the period, effective bed surge, rapid testing, high adherence to NPIs
#
# Median-case scenario (moderate suppression, capacity limited but functioning)
# - Cumulative infections: 150,000–180,000 (30–36%)
# - Hospitalizations: 7,500–9,000
# - Deaths: 900–1,800
# - Direct economic loss: $500–700 million (~25–35% of 6-month GDP)
# - Key drivers: Rt ~ 1.2–1.5, partial hospital saturation, moderate testing impact
#
# Worst-case scenario (surge and capacity constraints, limited control)
# - Cumulative infections: 300,000–350,000 (60–70%)
# - Hospitalizations: 25,000–32,000
# - Deaths: 3,500–5,000
# - Direct economic loss: $1.6–2.4 billion (roughly 80%–120% of 6-month GDP, or larger if the storm damages are included)
# - Key drivers: Rt ~ 1.7–2.3 for extended periods, delayed testing, hospital strain, ongoing power/water disruptions
#
# Notes on interpretation
# - These are scenario-based projections, not precise forecasts. They hinge on Rt evolution, hospital surge success, public compliance, and storm stabilization. The plan’s emphasis on rapid testing, field capacity, and data-driven gating aims to push outcomes toward the best-case end.
#
# (d) Three highest-value data collection/experiments to run in the next 7 days (and exact implementation)
#
# Experiment 1: Sentinel prevalence surveillance to estimate current infection burden and Rt
# - Objective: Provide a data-driven estimate of current prevalence and growth rate to calibrate Rt and NPIs.
# - Design and sample size: 15 sentinel sites (clinics/hospitals and community centers) with cross-sectional sampling of 50–100 asymptomatic/prioritized individuals per site per round; target 750–1,000 tests per week total (fits within daily testing capacity).
# - Implementation:
#   - Selection: 15 sentinel sites represent urban/rural mix and high-traffic hubs; appoint a site lead per location.
#   - Protocol: collect nasopharyngeal swabs (or rapid antigen if PCR turnaround is prohibitive) and test using PCR; track consent and data privacy.
#   - Timing: weekly rounds for 4–6 weeks; results reported within 48 hours of sample collection to the central dashboard.
#   - Data handling: standardize timestamps in the dataset, back-capture testing date, test type, and result; feed into Rt estimator dashboards.
# - Resources: ~$150k–$250k for test kits, logistics, personnel, and data integration.
#
# Experiment 2: Wastewater surveillance for community transmission signal
# - Objective: Early, non-invasive signal of community virus circulation to complement clinical testing.
# - Design: 6–8 catchment-area sites representing major population centers; collect 1 composite wastewater sample every 2–3 days per site.
# - Implementation:
#   - Partner with municipal wastewater teams; deploy grab/composite samplers; coordinate with a regional lab for RT-qPCR detection of viral RNA.
#   - Data workflow: daily upload of Ct values, convert to relative viral load, normalize by population, track trend over weeks.
# - Resources: ~$100k–$200k for samplers, lab reagents, transport, and data integration.
#
# Experiment 3: Data quality and clinical data augmentation pilot (to improve the hospital admission/death signal)
# - Objective: Improve the accuracy and timeliness of hospitalization and mortality signals from aggregate timestamps.
# - Design: implement a lightweight data-integration pilot across the functioning hospital and the expanding field clinics; align admissions, discharge, and death events with consistent date stamps; run a simple nowcasting model to adjust for delays.
# - Implementation:
#   - Agent-based liaison with hospital IT/records and field-clinic leads to standardize daily data feeds (even if timestamps are inconsistent now, collect a “date observed” field and a “date event occurred” field).
#   - Build a simple dashboard to monitor data completeness (missing fields, time-to-update, and consistency checks).
#   - Train a small data team to run daily checks and flag anomalies.
# - Resources: ~$100k for personnel, data tools, and minor IT upgrades.
#
# (Each experiment leverages the 1,000 tests/day limit and aims to improve the model inputs that drive policy decisions. They can be run in parallel within the $5M budget.)
#
# (e) Five distinct plan failure modes, mitigations, and early-warning indicators
#
# 1) Failure mode: Hospital surge capacity insufficient; system collapses under caseload
# - Mitigations: pre-activate field hospital beds; exceed surge capacity plan; rapid discharge and home-care enablement; inter-regional patient transfers if feasible.
# - Early-warning indicators: ICU occupancy > 70–80% of functional capacity; rising length of stay; rising oxygen usage per patient.
# - Trigger actions: activate field hospitals, reallocate staffing, widen NPIs, mobilize external support.
#
# 2) Failure mode: Critical power/water infrastructure failure or storm damage recurs
# - Mitigations: pre-position generators, water trucks, and fuel; prioritize hospital and water supply for clinics; establish alternate power routes and microgrids.
# - Early-warning indicators: utility outage durations; backup power usage above 60–70%; water pressure drops in clinics/hospitals.
# - Trigger actions: switch to emergency power plans; third-party emergency suppliers; alternate care sites.
#
# 3) Failure mode: Test turnaround delays or supply chain disruptions
# - Mitigations: activate on-site rapid testing in key clinics; deploy mobile labs or temporary labs; stockpile essential reagents; establish multiple suppliers.
# - Early-warning indicators: average test turnaround creeping beyond 48 hours; stockouts of kits/reagents; supply-chain delays reported by labs.
# - Trigger actions: shift to rapid point-of-care tests where validated; redeploy tests to highest-yield sites; adjust NPIs accordingly.
#
# 4) Failure mode: Data quality issues undermine decision-making
# - Mitigations: implement standardized data templates; require timestamped events; weekly data-quality reviews; independent data quality audits.
# - Early-warning indicators: rising proportion of missing timestamps; inconsistent case counts from sites; late nightly updates.
# - Trigger actions: pause unvalidated data feeds; invest in lightweight data-entry training; adjust modeling inputs to emphasize more robust signals (e.g., sentinel data, wastewater data).
#
# 5) Failure mode: Political interference or miscommunication erodes public trust
# - Mitigations: maintain transparent, nonpartisan communications; establish a trusted public health spokesperson; regular briefings with clear messaging; involve community leaders.
# - Early-warning indicators: public distrust metrics, social-media misinformation spikes, drop in compliance with NPIs.
# - Trigger actions: rapid correction statements; broaden community engagement; adjust messaging channels.
#
# Additional cross-cutting risks
# - Climate/storm timing could repeatedly disrupt operations; risk: schedule buffers for critical activities; ensure supply chain redundancy.
# - Economic fragility; risk: insufficient social protection for the most vulnerable; mitigate with targeted cash/food support where possible.
#
# (f) The three pieces of additional information that would most change the recommended course of action (and why)
#
# 1) Real-time Rt (effective reproduction number) and trend
# - Why it changes action: If Rt is reliably above 1.0 for a sustained period, more stringent NPIs and accelerated surge capacity become urgent; if Rt is consistently below 1.0, scale back interventions sooner, preserve resources, and avoid economic damage.
# - How to obtain now: derive Rt from sentinel testing, wastewater signals, and hospitalization trends in near real-time.
#
# 2) Real-time hospital capacity status (beds, ICU, oxygen, staffing, and time-to-full restoration)
# - Why it changes action: If the functioning hospital is overwhelmed or oxygen supply is unreliable, you must accelerate field hospital deployment, expedite crew rotations, and prioritize patient routing and home-care strategies; if capacity is more robust than feared, plan can be more targeted and less disruptive.
# - How to obtain now: formal daily capacity dashboard from the functioning hospital, field clinics, and any temporary facilities; oxygen and PPE stock level reporting.
#
# 3) Availability and delivery timeline for vaccines or antivirals (if any)
# - Why it changes action: Early vaccine or antiviral availability could shift the balance toward vaccination campaigns (if preventive) or rapid treatment, reducing hospitalizations and deaths; lack of vaccines/ antivirals emphasizes NPIs and health-system strengthening longer.
# - How to obtain now: procurement updates from national health authorities, procurement partners, and any regional or donor-based supply channels.
#
# Summary
# - The plan emphasizes rapid stabilization of critical infrastructure, targeted testing and surveillance enhancement, data-driven decision-making, targeted NPIs, and a data-informed approach to hospital surge capacity.
# - Best-case projections rely on strong Rt control and capacity to expand surge beds; median and worst-case reflect uncertainties in Rt, storm impact, and data quality.
# - The three experiments (sentinel prevalence, wastewater surveillance, and data-quality augmentation) provide higher-quality inputs to Rt and trend estimates without requiring prohibitive resources.
# - The five failure modes address the most probable systemic gaps, with concrete mitigations and early-warning indicators to trigger timely action.
# - The three items of information most likely to alter the plan are Rt dynamics, real-time hospital capacity, and vaccine/antiviral availability; obtaining them immediately would substantially refine the recommended actions.
#
# If you’d like, I can translate this into a one-page executive brief with a compact budget table, a simple dashboard mock-up, and a 2-week milestone plan tailored to your country’s actual governance structure and procurement channels.

# %%
# Anthropic has a slightly different API, and Max Tokens is required

model_name = "claude-sonnet-4-5"

claude = Anthropic()
response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
answer = response.content[0].text

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
model_name = "gemini-2.5-flash"

response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com/v1")
model_name = "deepseek-chat"

response = deepseek.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# Updated with the latest Open Source model from OpenAI

groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")
model_name = "openai/gpt-oss-120b"

response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# !ollama pull llama3.2

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "llama3.2"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# So where are we?

print(competitors)
print(answers)

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!

openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>
